# %%
#importing required libraries
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers

# %%
#downloading div2k data from tf datasets
div2k_data = tfds.image.Div2k(config="bicubic_x4")
div2k_data.download_and_prepare()
# Out:
# WARNING:absl:DEPRECATED! Do not use a DatasetBuilder class directly, but call `tfds.builder_cls('div2k')`.

# %%
#training data
train = div2k_data.as_dataset(split='train',as_supervised=True)
train_cache = train.cache()

#validation data
val= div2k_data.as_dataset(split='validation',as_supervised=True)
val_cache = val.cache()

# %%
#flip image
def flip_left_right(lowres_img,highres_img):

  #creating a random possible values
  random = tf.random.uniform(shape=(),maxval=1)

  #2 possibilites - flip or not
  #<0.5 - don't flip  >0.5 - flip
  if random < 0.5:
    return (lowres_img,highres_img)
  else:
    return (tf.image.flip_left_right(lowres_img),tf.image.flip_left_right(highres_img))

# %%
#rotation of image
def random_rotate(lowres_img,highres_img):
  #rotation of images by 90
  random = tf.random.uniform(shape=(),maxval=4,dtype=tf.int32)
  #here random values are between 0 to 4. So that an image can be rotated.

  return tf.image.rot90(lowres_img,random), tf.image.rot90(highres_img,random)

# %%
#cropping image
def random_crop(lowres_img,highres_img,hr_crop_size=96,scale=4):
  '''
  low resolution = 24 x 24
  high resolution = 96 x 96
  '''

  low_crop_size = hr_crop_size//scale
  low_img_shape = tf.shape(lowres_img)[:2]  # height , weight

  low_width = tf.random.uniform(shape=(),maxval = low_img_shape[1] - low_crop_size + 1,dtype= tf.int32)
  low_height = tf.random.uniform(shape=(),maxval = low_img_shape[0] - low_crop_size + 1,dtype= tf.int32)

  high_width = low_width * scale
  high_height = low_height * scale

  low_img_cropped = lowres_img[low_height : low_height + low_crop_size,low_width : low_width + low_crop_size,]
  #24 x 24
  high_img_cropped = highres_img[high_height: high_height + hr_crop_size,high_width : high_width + hr_crop_size,]
  #96 x 96
  return low_img_cropped,high_img_cropped

# %%
#data augmentation
def dataset_object(dataset_cache, training = True):
  ds = dataset_cache
  ds = ds. map(lambda lowres, highres: random_crop(lowres,highres,scale=4))

  if training:
    ds = ds.map(random_rotate)
    ds = ds.map(flip_left_right)

  ds = ds.batch(16)
  ds = ds.prefetch(buffer_size=160)
  return ds

# %%
train_ds = dataset_object(train_cache,training = True)
val_ds = dataset_object(val_cache,training = False)

# %%
#sample images
lowres, highres = next(iter(train_ds))

##high resolution image
plt.figure(figsize=(10,10))
for i in range(3):
  ax = plt.subplot(3,3,i+1)
  plt.imshow(highres[i].numpy().astype("uint8"))
  plt.title(highres[i].shape)
  plt.axis("off")


##low resolution image
plt.figure(figsize=(10,10))
for i in range(3):
  ax= plt.subplot(3,3,i+1)
  plt.imshow(lowres[i].numpy().astype("uint8"))
  plt.title(lowres[i].shape)
  plt.axis("off")

# %%
@keras.saving.register_keras_serializable()
def PSNR(super_res,high_res):
  psnr = tf.image.psnr(high_res,super_res,max_val=255)[0]
  return psnr

# %%
@keras.saving.register_keras_serializable()
class EDSRModel(tf.keras.Model):
  def train_step(self,data):
    x,y = data
    with tf.GradientTape() as tape:
      y_pred = self(x, training = True)  # forward pass
      #loss function
      loss = self.compiled_loss(y,y_pred,regularization_losses = self.losses)

    #gradient values
    trainable_vars = self.trainable_variables
    gradients = tape.gradient(loss,trainable_vars)
    # weights update
    self.optimizer.apply_gradients(zip(gradients,trainable_vars))
    self.compiled_metrics.update_state(y,y_pred)
    return {i.name: i.result() for i in self.metrics }
  def predict_step(self,x):
    x = tf.cast(tf.expand_dims(x,axis=0),tf.float32) #dummy dimension
    super_resolution_img = self(x,training = False) #image to model
    super_resolution_img = tf.clip_by_value(super_resolution_img,0,255)
    super_resolution_img = tf.round(super_resolution_img)
    super_resolution_img = tf.squeeze(tf.cast(super_resolution_img,tf.uint8), axis=0)
    return super_resolution_img

# %%
@keras.saving.register_keras_serializable()
#residual blocks
def ResBlock(input):
  x = layers.Conv2D(64,3,padding='same',activation='relu')(input)
  x = layers.Conv2D(64,3,padding='same')(x)
  x = layers.Add()([input,x])
  return x

# %%
@keras.saving.register_keras_serializable()
#upsampling block
def Upsampling(input, factor = 2, **kwargs):
  x = layers.Conv2D(64*(factor**2),3,padding='same',**kwargs)(input)
  x = tf.nn.depth_to_space(x,block_size = factor)
  x = layers.Conv2D(64*(factor**2),3,padding='same',**kwargs)(x)
  x = tf.nn.depth_to_space(x,block_size=factor)
  return x

# %%
@keras.saving.register_keras_serializable()
#making model
def make_model(num_filters,num_of_residual_blocks):
  input_layer = layers.Input(shape=(None,None,3))
  #scaling values
  x = layers.Rescaling(scale=1.0/255)(input_layer)
  x = x_new = layers.Conv2D(num_filters,3,padding='same')(x)
  #16 residual blocks
  for i in range(num_of_residual_blocks):
    x_new = ResBlock(x_new)

  x_new = layers.Conv2D(num_filters,3,padding='same')(x_new)
  x = layers.Add()([x,x_new])

  x = Upsampling(x)
  x = layers.Conv2D(3,3,padding='same')(x)

  output_layer = layers.Rescaling(scale=255)(x)
  return EDSRModel(input_layer,output_layer)

# %%
model = make_model(num_filters=64,num_of_residual_blocks=16)

# %%
#model.summary()
# Out:
# Model: "edsr_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  rescaling (Rescaling)       (None, None, None, 3)        0         ['input_1[0][0]']
#
#  conv2d (Conv2D)             (None, None, None, 64)       1792      ['rescaling[0][0]']
#
#  conv2d_1 (Conv2D)           (None, None, None, 64)       36928     ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, None, None, 64)       36928     ['conv2d_1[0][0]']
#
#  add (Add)                   (None, None, None, 64)       0         ['conv2d[0][0]',
#                                                                      'conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, None, None, 64)       36928     ['add[0][0]']
#
#  conv2d_4 (Conv2D)           (None, None, None, 64)       36928     ['conv2d_3[0][0]']
#
#  add_1 (Add)                 (None, None, None, 64)       0         ['add[0][0]',
#                                                                      'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, None, None, 64)       36928     ['add_1[0][0]']
#
#  conv2d_6 (Conv2D)           (None, None, None, 64)       36928     ['conv2d_5[0][0]']
#
#  add_2 (Add)                 (None, None, None, 64)       0         ['add_1[0][0]',
#                                                                      'conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, None, None, 64)       36928     ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)           (None, None, None, 64)       36928     ['conv2d_7[0][0]']
#
#  add_3 (Add)                 (None, None, None, 64)       0         ['add_2[0][0]',
#                                                                      'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, None, None, 64)       36928     ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_9[0][0]']
#
#  add_4 (Add)                 (None, None, None, 64)       0         ['add_3[0][0]',
#                                                                      'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, None, None, 64)       36928     ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_11[0][0]']
#
#  add_5 (Add)                 (None, None, None, 64)       0         ['add_4[0][0]',
#                                                                      'conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, None, None, 64)       36928     ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_13[0][0]']
#
#  add_6 (Add)                 (None, None, None, 64)       0         ['add_5[0][0]',
#                                                                      'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, None, None, 64)       36928     ['add_6[0][0]']
#
#  conv2d_16 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_15[0][0]']
#
#  add_7 (Add)                 (None, None, None, 64)       0         ['add_6[0][0]',
#                                                                      'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, None, None, 64)       36928     ['add_7[0][0]']
#
#  conv2d_18 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_17[0][0]']
#
#  add_8 (Add)                 (None, None, None, 64)       0         ['add_7[0][0]',
#                                                                      'conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)          (None, None, None, 64)       36928     ['add_8[0][0]']
#
#  conv2d_20 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_19[0][0]']
#
#  add_9 (Add)                 (None, None, None, 64)       0         ['add_8[0][0]',
#                                                                      'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)          (None, None, None, 64)       36928     ['add_9[0][0]']
#
#  conv2d_22 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_21[0][0]']
#
#  add_10 (Add)                (None, None, None, 64)       0         ['add_9[0][0]',
#                                                                      'conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)          (None, None, None, 64)       36928     ['add_10[0][0]']
#
#  conv2d_24 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_23[0][0]']
#
#  add_11 (Add)                (None, None, None, 64)       0         ['add_10[0][0]',
#                                                                      'conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)          (None, None, None, 64)       36928     ['add_11[0][0]']
#
#  conv2d_26 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_25[0][0]']
#
#  add_12 (Add)                (None, None, None, 64)       0         ['add_11[0][0]',
#                                                                      'conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)          (None, None, None, 64)       36928     ['add_12[0][0]']
#
#  conv2d_28 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_27[0][0]']
#
#  add_13 (Add)                (None, None, None, 64)       0         ['add_12[0][0]',
#                                                                      'conv2d_28[0][0]']
#
#  conv2d_29 (Conv2D)          (None, None, None, 64)       36928     ['add_13[0][0]']
#
#  conv2d_30 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_29[0][0]']
#
#  add_14 (Add)                (None, None, None, 64)       0         ['add_13[0][0]',
#                                                                      'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)          (None, None, None, 64)       36928     ['add_14[0][0]']
#
#  conv2d_32 (Conv2D)          (None, None, None, 64)       36928     ['conv2d_31[0][0]']
#
#  add_15 (Add)                (None, None, None, 64)       0         ['add_14[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)          (None, None, None, 64)       36928     ['add_15[0][0]']
#
#  add_16 (Add)                (None, None, None, 64)       0         ['conv2d[0][0]',
#                                                                      'conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)          (None, None, None, 256)      147712    ['add_16[0][0]']
#
#  tf.nn.depth_to_space (TFOp  (None, None, None, 64)       0         ['conv2d_34[0][0]']
#  Lambda)
#
#  conv2d_35 (Conv2D)          (None, None, None, 256)      147712    ['tf.nn.depth_to_space[0][0]']
#
#  tf.nn.depth_to_space_1 (TF  (None, None, None, 64)       0         ['conv2d_35[0][0]']
#  OpLambda)
#
#  conv2d_36 (Conv2D)          (None, None, None, 3)        1731      ['tf.nn.depth_to_space_1[0][0]
#                                                                     ']
#
#  rescaling_1 (Rescaling)     (None, None, None, 3)        0         ['conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 1517571 (5.79 MB)
# Trainable params: 1517571 (5.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
#Adam optimizer
optim_edsr = keras.optimizers.Adam(
    learning_rate=keras.optimizers.schedules.PiecewiseConstantDecay(
        boundaries=[5000], values=[1e-4, 5e-5]
    )
  )
#loss for psnr
model.compile(optimizer=optim_edsr, loss="mae", metrics=[PSNR])
#training
model.fit(train_ds.repeat(), epochs=100, steps_per_epoch=250,batch_size=32,validation_data=val_ds)
model.save('edsr_model.keras')
# Out:
# Epoch 1/100
# 250/250 [==============================] - 118s 289ms/step - loss: 24.1535 - PSNR: 21.0149 - val_loss: 12.8537 - val_PSNR: 24.4394
# Epoch 2/100
# 250/250 [==============================] - 9s 37ms/step - loss: 11.6185 - PSNR: 25.6459 - val_loss: 10.8767 - val_PSNR: 25.2559
# Epoch 3/100
# 250/250 [==============================] - 9s 37ms/step - loss: 10.1221 - PSNR: 27.3572 - val_loss: 9.6827 - val_PSNR: 28.0594
# Epoch 4/100
# 250/250 [==============================] - 9s 37ms/step - loss: 9.2318 - PSNR: 28.6338 - val_loss: 9.2837 - val_PSNR: 29.7964
# Epoch 5/100
# 250/250 [==============================] - 9s 36ms/step - loss: 8.8462 - PSNR: 29.4918 - val_loss: 8.1597 - val_PSNR: 28.9102
# Epoch 6/100
# 250/250 [==============================] - 9s 38ms/step - loss: 8.5067 - PSNR: 29.8030 - val_loss: 8.7798 - val_PSNR: 28.6411
# Epoch 7/100
# 250/250 [==============================] - 9s 38ms/step - loss: 8.5145 - PSNR: 29.1893 - val_loss: 8.5648 - val_PSNR: 28.1491
# Epoch 8/100
# 250/250 [==============================] - 9s 36ms/step - loss: 8.3028 - PSNR: 29.9534 - val_loss: 7.4628 - val_PSNR: 30.0600
# Epoch 9/100
# 250/250 [==============================] - 9s 37ms/step - loss: 8.1937 - PSNR: 29.4101 - val_loss: 7.8827 - val_PSNR: 30.2654
# Epoch 10/100
# 250/250 [==============================] - 9s 37ms/step - loss: 8.0852 - PSNR: 30.0591 - val_loss: 7.8111 - val_PSNR: 31.3855
# Epoch 11/100
# 250/250 [==============================] - 9s 37ms/step - loss: 8.0143 - PSNR: 30.0155 - val_loss: 8.3859 - val_PSNR: 26.9975
# Epoch 12/100
# 250/250 [==============================] - 9s 36ms/step - loss: 8.0354 - PSNR: 29.7226 - val_loss: 7.3062 - val_PSNR: 32.1926
# Epoch 13/100
# 250/250 [==============================] - 9s 37ms/step - loss: 7.8107 - PSNR: 30.4601 - val_loss: 7.8677 - val_PSNR: 28.6232
# Epoch 14/100
# 250/250 [==============================] - 9s 37ms/step - loss: 7.8906 - PSNR: 30.0529 - val_loss: 7.2581 - val_PSNR: 29.2431
# Epoch 15/100
# 250/250 [==============================] - 9s 37ms/step - loss: 7.8997 - PSNR: 30.8115 - val_loss: 8.1643 - val_PSNR: 27.7595
# Epoch 16/100
# 250/250 [==============================] - 9s 36ms/step - loss: 7.7519 - PSNR: 31.2961 - val_loss: 7.6759 - val_PSNR: 33.8799
# Epoch 17/100
# 250/250 [==============================] - 9s 37ms/step - loss: 7.6021 - PSNR: 31.2765 - val_loss: 7.4753 - val_PSNR: 32.9255
# Epoch 18/100
# 250/250 [==============================] - 9s 37ms/step - loss: 7.6476 - PSNR: 32.1724 - val_loss: 8.1681 - val_PSNR: 29.9664
# Epoch 19/100
# 250/250 [==============================] - 9s 36ms/step - loss: 7
100
# 250/250 [==============================] - 9s 37ms/step - loss: 7.0333 - PSNR: 31.2607 - val_loss: 6.8232 - val_PSNR: 30.0628
# Epoch 78/100
# 250/250 [==============================] - 9s 36ms/step - loss: 6.9391 - PSNR: 32.8291 - val_loss: 7.8154 - val_PSNR: 30.3707
# Epoch 79/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.9959 - PSNR: 32.6620 - val_loss: 6.9961 - val_PSNR: 28.8880
# Epoch 80/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.8684 - PSNR: 33.0066 - val_loss: 6.2366 - val_PSNR: 31.3670
# Epoch 81/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.8923 - PSNR: 32.9350 - val_loss: 7.0628 - val_PSNR: 31.7080
# Epoch 82/100
# 250/250 [==============================] - 9s 36ms/step - loss: 7.0696 - PSNR: 33.2561 - val_loss: 7.2937 - val_PSNR: 27.8729
# Epoch 83/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.9303 - PSNR: 32.7147 - val_loss: 7.3092 - val_PSNR: 30.9754
# Epoch 84/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.9650 - PSNR: 31.9334 - val_loss: 7.0869 - val_PSNR: 32.2074
# Epoch 85/100
# 250/250 [==============================] - 9s 37ms/step - loss: 7.1026 - PSNR: 32.8678 - val_loss: 6.3983 - val_PSNR: 35.8274
# Epoch 86/100
# 250/250 [==============================] - 9s 36ms/step - loss: 6.9601 - PSNR: 32.8855 - val_loss: 7.4609 - val_PSNR: 33.1118
# Epoch 87/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.7896 - PSNR: 32.3050 - val_loss: 6.8996 - val_PSNR: 28.2156
# Epoch 88/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.8825 - PSNR: 33.5539 - val_loss: 6.0211 - val_PSNR: 30.6723
# Epoch 89/100
# 250/250 [==============================] - 9s 36ms/step - loss: 6.8555 - PSNR: 32.2942 - val_loss: 6.9458 - val_PSNR: 30.4542
# Epoch 90/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.9940 - PSNR: 31.8200 - val_loss: 6.8124 - val_PSNR: 32.4999
# Epoch 91/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.8832 - PSNR: 32.4941 - val_loss: 6.4975 - val_PSNR: 33.8900
# Epoch 92/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.9089 - PSNR: 32.9139 - val_loss: 6.6726 - val_PSNR: 38.5616
# Epoch 93/100
# 250/250 [==============================] - 9s 36ms/step - loss: 6.7432 - PSNR: 33.1443 - val_loss: 6.6287 - val_PSNR: 30.2791
# Epoch 94/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.9390 - PSNR: 32.3990 - val_loss: 6.2147 - val_PSNR: 30.8393
# Epoch 95/100
# 250/250 [==============================] - 9s 38ms/step - loss: 6.8325 - PSNR: 32.7812 - val_loss: 6.3345 - val_PSNR: 34.5275
# Epoch 96/100
# 250/250 [==============================] - 9s 36ms/step - loss: 6.7480 - PSNR: 33.1797 - val_loss: 6.2789 - val_PSNR: 31.7926
# Epoch 97/100
# 250/250 [==============================] - 9s 36ms/step - loss: 6.8677 - PSNR: 32.0899 - val_loss: 6.9101 - val_PSNR: 33.3062
# Epoch 98/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.9011 - PSNR: 32.2000 - val_loss: 5.6550 - val_PSNR: 34.6733
# Epoch 99/100
# 250/250 [==============================] - 9s 37ms/step - loss: 6.8718 - PSNR: 32.3338 - val_loss: 6.0328 - val_PSNR: 33.9904
# Epoch 100/100
# 250/250 [==============================] - 9s 36ms/step - loss: 6.9097 - PSNR: 32.5757 - val_loss: 6.8409 - val_PSNR: 29.3108

# %%
def plot_results(lowres_img,prediction):
  plt.figure(figsize=(24,14))
  plt.subplot(132), plt.imshow(lowres_img), plt.title('Low resolution')
  plt.subplot(133), plt.imshow(prediction), plt.title('Prediction')
  plt.show()
model = tf.keras.models.load_model('edsr_model.keras')
for lowres,highres in val.take(2):
  lowres = tf.image.random_crop(lowres,(150,150,3))
  prediction = model.predict_step(lowres)
  plot_results(lowres,prediction)
